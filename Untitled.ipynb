# %%
import pandas as pd

# %%
df = pd.read_excel("sf.xls")

# %%
df
# Out:
#                    Date  #blocks        #btc         SF         price  \
# 0                   NaT      NaN         NaN        NaN           NaN
# 1   2009-01-01 01:00:00   2543.0    127150.0        NaN           NaN
# 2   2009-02-01 01:00:00   3380.0    296150.0        NaN           NaN
# 3   2009-03-01 01:00:00   3466.0    469450.0        NaN           NaN
# 4   2009-04-01 02:00:00   3442.0    641550.0        NaN           NaN
# 5   2009-05-01 02:00:00   3383.0    810700.0        NaN           NaN
# 6   2009-06-01 02:00:00   2236.0    922500.0        NaN           NaN
# 7   2009-07-01 02:00:00   1925.0   1018750.0        NaN           NaN
# 8   2009-08-01 02:00:00   1564.0   1096950.0        NaN           NaN
# 9   2009-09-01 02:00:00   2159.0   1204900.0        NaN           NaN
# 10  2009-10-01 02:00:00   2126.0   1311200.0   0.145931      0.000764
# 11  2009-11-01 01:00:00   2217.0   1422050.0   0.219854      0.002000
# ...

# %%
blkchain_df = pd.read_excel("btcchaindata.xls")

# %%
blkchain_df
# Out:
#      year  month  monthdays      #txs  blockheight   timestamp  #txlastblock  \
# 0    2009      1         31      2576         2543  1233446375             1
# 1    2009      2         28      3417         5923  1235865487             1
# 2    2009      3         31      3487         9389  1238542962             1
# 3    2009      4         30      3459        12831  1241135617             1
# 4    2009      5         31      3401        16214  1243798067             1
# 5    2009      6         30      2244        18450  1246405838             1
# 6    2009      7         31      1930        20375  1249083183             1
# 7    2009      8         31      1570        21939  1251762775             1
# 8    2009      9         30      2170        24098  1254354212             1
# 9    2009     10         31      2139        26224  1257033018             1
# 10   2009     11         30      2232        28441  1259625429             1
# ...
